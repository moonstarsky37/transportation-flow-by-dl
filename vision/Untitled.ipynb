# %%
import numpy as np

# %%
predict=np.load('predict_conv_c_1.npy')
label = np.load('label.npy')

# %%
predict.shape
# Out:
# (1, 64, 19, 18)

# %%
label.shape
# Out:
# (2, 19, 18)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
#plt.figure(figsize=(8,8))
f, ((ax1, ax2,ax3,ax4),(ax5,ax6,ax7,ax8),(ax9,ax10,ax11,ax12),(ax13,ax14,ax15,ax16)) = plt.subplots(figsize=(18,14),nrows=4,ncols=4)
ax_=((ax1, ax2,ax3,ax4),(ax5,ax6,ax7,ax8),(ax9,ax10,ax11,ax12),(ax13,ax14,ax15,ax16))
for i in range(4):
    for j in range(4):
        index =int(i*4+j)
        sns.heatmap(predict[0,index,:], ax=ax_[i][j]).invert_yaxis()

# %%
f, (ax1, ax2) = plt.subplots(figsize=(18,6),ncols=2)
sns.heatmap(label[0,:], ax=ax1).invert_yaxis()
sns.heatmap(label[1,:], ax=ax2).invert_yaxis()

# %%
label.shape
# Out:
# (2, 19, 18)

# %%
import imageio
# imageio.mimwrite('output_filename.mp4', np_array , fps = [an int])

# %%
predict = np.load('../result/STresnet_prediction.npy')
groundtruth = np.load('../result/STresnet_groundtruth.npy')

# %%
predict_data=(predict/2+0.5)*45
groundtruth_data = (groundtruth/2+0.5)*45

# %%
import cv2
import numpy as np
import glob
glob.glob('../result/vis_results/*.jpg')
img_array = []
for filename in glob.glob('C:/New folder/Images/*.jpg'):
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)
 
 
# out = cv2.VideoWriter('project.avi',cv2.VideoWriter_fourcc(*'DIVX'), 15, size)
 
# for i in range(len(img_array)):
#     out.write(img_array[i])
# out.release()
# Out:
# 3090

# %%
import os, glob
import moviepy.video.io.ImageSequenceClip
image_folder='../result/vis_results/'
fps=25

image_files = glob.glob('../result/vis_results/*.jpg')
clip = moviepy.video.io.ImageSequenceClip.ImageSequenceClip(image_files, fps=fps)
clip.write_videofile('my_video.mp4')
# Out:
# t:   0%|          | 4/3178 [00:00<01:32, 34.48it/s, now=None]Moviepy - Building video my_video.mp4.
# Moviepy - Writing video my_video.mp4
#
# t: 100%|█████████▉| 3176/3178 [01:39<00:00, 34.30it/s, now=None]Moviepy - Done !
# Moviepy - video ready my_video.mp4

# %%
import pandas as pd

# %%
df = pd.read_csv("../../train.csv")

# %%
df["pickup_datetime"] = pd.to_datetime(df["pickup_datetime"])

# %%
df.head()
# Out:
#           id  vendor_id     pickup_datetime     dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# ...

# %%
 df[df["pickup_datetime"].dt.strftime('%Y-%m-%d').between('2016-01-01','2016-03-01')]
# Out:
#                 id  vendor_id     pickup_datetime     dropoff_datetime  \
# 2        id3858529          2 2016-01-19 11:35:24  2016-01-19 12:10:48
# 5        id0801584          2 2016-01-30 22:01:40  2016-01-30 22:09:03
# 12       id1187965          2 2016-02-19 09:52:46  2016-02-19 10:11:20
# 20       id2070428          1 2016-02-28 02:23:02  2016-02-28 02:31:08
# 25       id0129640          2 2016-02-14 13:27:56  2016-02-14 13:49:19
# ...            ...        ...                 ...                  ...
# 1458626  id0155863          2 2016-01-17 17:21:11  2016-01-17 17:25:15
# 1458636  id0405770          2 2016-02-12 10:13:06  2016-02-12 10:26:26
# 1458638  id1454193          2 2016-02-02 00:39:39  2016-02-02 00:46:33
# 1458640  id1049543          1 2016-01-10 07:35:15  2016-01-10 07:46:10
# 1458642  id2714485          1 2016-01-05 15:56:26  2016-01-05 16:02:39
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# ...

# %%
df["pickup_datetime"].max()
# Out:
# Timestamp('2016-06-30 23:59:39')

# %%
import numpy as np
np.load("../../X.npy").shape
# Out:
# (1530, 32, 32)
